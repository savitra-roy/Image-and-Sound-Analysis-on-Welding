# %%
import pandas as pd

df = pd.read_excel('data.xlsx', nrows=28, usecols=range(7))

# %%
df
# Out:
#     Sl. No  feed rate(mm/min)  current (Amperes)  TV(mm/min)  widht(mm)  \
# 0        1               1800                120          50      6.889
# 1        2               1200                120          50      5.944
# 2        3               2400                120          50      7.718
# 3        4               1800                140          50      7.821
# 4        5               1200                140          50      6.978
# 5        6               2400                140          50      7.645
# 6        7               1800                100          50      5.735
# 7        8               1200                100          50      6.568
# 8        9               2400                100          50      8.005
# 9       10               1800                120          75      5.618
# 10      11               1200                120          75      5.219
# 11      12               2400                120          75      6.736
# ...

# %%
df.isna().sum()
# Out:
# Sl. No               0
# feed rate(mm/min)    0
# current (Amperes)    0
# TV(mm/min)           0
# widht(mm)            0
# height(mm)           0
# rms                  1
# dtype: int64

# %%
df['rms'].fillna(df['rms'].mean(), inplace=True)
# Out:
# <ipython-input-4-ed297be1b565>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rms'].fillna(df['rms'].mean(), inplace=True)

# %%
df.columns[0]
# Out:
# 'Sl. No'

# %%
df.drop(columns=df.columns[0], inplace=True)

# %%
df
# Out:
#     feed rate(mm/min)  current (Amperes)  TV(mm/min)  widht(mm)  height(mm)  \
# 0                1800                120          50      6.889      4.7690
# 1                1200                120          50      5.944      3.8230
# 2                2400                120          50      7.718      5.6213
# 3                1800                140          50      7.821      4.4970
# 4                1200                140          50      6.978      2.9730
# 5                2400                140          50      7.645      4.3820
# 6                1800                100          50      5.735      4.2990
# 7                1200                100          50      6.568      4.7980
# 8                2400                100          50      8.005      6.1780
# 9                1800                120          75      5.618      4.3860
# 10               1200                120          75      5.219      3.1580
# ...

# %%
df.corr()
# Out:
#                    feed rate(mm/min)  current (Amperes)    TV(mm/min)  \
# feed rate(mm/min)       1.000000e+00       2.526374e-17  6.736998e-18
# current (Amperes)       2.526374e-17       1.000000e+00  5.179067e-16
# TV(mm/min)              6.736998e-18       5.179067e-16  1.000000e+00
# widht(mm)               3.450495e-01       3.628426e-01 -7.869634e-01
# height(mm)              6.317518e-01      -3.450095e-01 -5.713291e-01
# rms                     3.748454e-01       1.510160e-01 -2.382192e-01
#
#                    widht(mm)  height(mm)       rms
# feed rate(mm/min)   0.345050    0.631752  0.374845
# current (Amperes)   0.362843   -0.345010  0.151016
# TV(mm/min)         -0.786963   -0.571329 -0.238219
# widht(mm)           1.000000    0.595475  0.495424
# height(mm)          0.595475    1.000000  0.272973
# rms                 0.495424    0.272973  1.000000

# %%
df['hbyw']= df['height(mm)']/ df['widht(mm)']

# %%
df.drop(columns=['height(mm)', 'widht(mm)'], inplace=True)

# %%
df
# Out:
#     feed rate(mm/min)  current (Amperes)  TV(mm/min)       rms      hbyw
# 0                1800                120          50  0.770000  0.692263
# 1                1200                120          50  0.430000  0.643170
# 2                2400                120          50  1.140000  0.728336
# 3                1800                140          50  0.510000  0.574990
# 4                1200                140          50  0.610000  0.426053
# 5                2400                140          50  1.000000  0.573185
# 6                1800                100          50  0.530000  0.749608
# 7                1200                100          50  0.650000  0.730512
# 8                2400                100          50  0.800000  0.771768
# 9                1800                120          75  0.360000  0.780705
# 10               1200                120          75  0.410000  0.605097
# 11               2400                120          75  0.500000  0.716449
# ...

# %%
X = df['hbyw'].apply(lambda x: 1 if 0.3 <= x <= 0.7 else 0)

# %%
X
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     1
# 5     1
# 6     0
# 7     0
# 8     0
# 9     0
# 10    1
# 11    0
# 12    1
# 13    1
# 14    0
# 15    0
# 16    1
# 17    0
# 18    0
# 19    1
# 20    0
# 21    1
# 22    1
# 23    1
# 24    0
# 25    0
# 26    0
# Name: hbyw, dtype: int64

# %%
df['Weld']=X

# %%
df
# Out:
#     feed rate(mm/min)  current (Amperes)  TV(mm/min)       rms      hbyw  Weld
# 0                1800                120          50  0.770000  0.692263     1
# 1                1200                120          50  0.430000  0.643170     1
# 2                2400                120          50  1.140000  0.728336     0
# 3                1800                140          50  0.510000  0.574990     1
# 4                1200                140          50  0.610000  0.426053     1
# 5                2400                140          50  1.000000  0.573185     1
# 6                1800                100          50  0.530000  0.749608     0
# 7                1200                100          50  0.650000  0.730512     0
# 8                2400                100          50  0.800000  0.771768     0
# 9                1800                120          75  0.360000  0.780705     0
# 10               1200                120          75  0.410000  0.605097     1
# ...

# %%
df.columns = ['feed_rate', 'current', 'TV','rms','hbyw','weld']

# %%
df
# Out:
#     feed_rate  current   TV       rms      hbyw  weld
# 0        1800      120   50  0.770000  0.692263     1
# 1        1200      120   50  0.430000  0.643170     1
# 2        2400      120   50  1.140000  0.728336     0
# 3        1800      140   50  0.510000  0.574990     1
# 4        1200      140   50  0.610000  0.426053     1
# 5        2400      140   50  1.000000  0.573185     1
# 6        1800      100   50  0.530000  0.749608     0
# 7        1200      100   50  0.650000  0.730512     0
# 8        2400      100   50  0.800000  0.771768     0
# 9        1800      120   75  0.360000  0.780705     0
# 10       1200      120   75  0.410000  0.605097     1
# 11       2400      120   75  0.500000  0.716449     0
# 12       1800      140   75  0.722000  0.578864     1
# 13       1200      140   75  0.630115  0.351544     1
# 14       2400      140   75  0.630000  0.746477     0
# 15       1800      100   75  0.546000  0.835223     0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
X= df.drop(columns=['hbyw','weld'])
y= df['weld']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model= SVC(kernel= 'rbf')

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred= model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.40      0.57         5
#
#     accuracy                           0.67         9
#    macro avg       0.79      0.70      0.65         9
# weighted avg       0.81      0.67      0.64         9

# %%
from sklearn.metrics import hinge_loss

# %%
train_decision = model.decision_function(X_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3862964f2efc> in <cell line: 0>()
# ----> 1 train_decision = model.decision_function(X_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in decision_function(self, X)
#     785         transformation of ovo decision function.
#     786         """
# --> 787         dec = self._decision_function(X)
#     788         if self.decision_function_shape == "ovr" and len(self.classes_) > 2:
#     789             return _ovr_decision_function(dec < 0, -dec, len(self.classes_))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in _decision_function(self, X)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-63433b3928d2> in <cell line: 0>()
# ----> 1 plot_decision_boundary(model, X_pca, y)
#
# <ipython-input-30-d5ca9998cc6d> in plot_decision_boundary(model, X, y)
#       2     x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
#       3     y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
# ----> 4     xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
#       5                          np.arange(y_min, y_max, 0.01))
#       6
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py in meshgrid(copy, sparse, indexing, *xi)
#    5385
#    5386     if copy:
# -> 5387         output = tuple(x.copy() for x in output)
#    5388
#    5389     return output
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py in <genexpr>(.0)
#    5385
#    5386     if copy:
# ...
